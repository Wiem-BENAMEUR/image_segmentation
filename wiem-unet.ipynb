# %%
import tensorflow as tf
import tensorflow.keras.layers as tfl
import os
from tqdm import tqdm
import cv2
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
from PIL import Image
from os.path import splitext

# %% [markdown]
#  <div style="color:black;
#            display:fill;
#            border-radius:5px;
#            font-size:300%;
#            font-family: Times New Roman, Times, serif;
#     letter-spacing:0.5px"><b>Loading Data & Data Preprocessing</b>
#
# <p style="padding: 10px;color:black;font-size:40%;font-family: Times New Roman, Times, serif;">First using the OS library I'll upload the cityscapes pair images.</p>

# %%
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
path='../input/cityscapes-image-pairs'
def images_upload(path):
    images=[]
    for root,subfolders,files in os.walk(path):
        for file in tqdm(files):
            filename=root+os.sep+file
            if filename.endswith('jpg') or filename.endwith('png'):
                images.append(filename)
    return images
images=images_upload(path)
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 100%|██████████| 500/500 [00:00<00:00, 1044398.41it/s]
# 100%|██████████| 2975/2975 [00:00<00:00, 1214527.39it/s]
# 100%|██████████| 500/500 [00:00<00:00, 576774.48it/s]
# 100%|██████████| 2975/2975 [00:00<00:00, 1337268.72it/s]

# %%
def convert_image_rgb(data):
    imgs=[]
    for i in tqdm(data):
        img = cv2.imread(i,cv2.COLOR_BGR2RGB)
        del i
        imgs.append(img)
    return imgs
img=convert_image_rgb(images)
# Out:
# 100%|██████████| 6950/6950 [01:09<00:00, 100.27it/s]

# %% [markdown]
# <p style="padding: 10px;color:black;font-size:120%;font-family: Times New Roman, Times, serif;">Let us look at one of the images. It can be seen that the image contains both the real image and the mask, so the next task will be to distinguish between them. Randmoly has selected the following image.</p>

# %%
plt.imshow(img[np.random.randint(0,len(img))]);

# %% [markdown]
# <p style="padding: 10px;color:black;font-size:120%;font-family: Times New Roman, Times, serif;">Because the image shape is 512*256, it should be divided into two groups, real images and mask images, at 256 pixels on the x axis.</p>

# %%
def split_input_mask(data):
    inputs=[]
    mask=[]
    for i in data:
        a=i[:,:256]
        inputs.append(a)
        b=i[:,256:]
        mask.append(b)
    return inputs,mask
inputs,mask=split_input_mask(img)

# %%
del images
del img

# %% [markdown]
# <p style="padding: 10px;color:black;font-size:120%;font-family: Times New Roman, Times, serif;">In this section, I'll show a few images of the real images as well as a few images of the mask images after they've been separated.</p>

# %%
def show_images(data):
    plt.figure(figsize=(10,10))
    for i in range(9):
        idx=np.random.randint(0,len(data))
        plt.subplot(3,3,i+1)
        img=data[idx]
        plt.imshow(img)
show_images(inputs)

# %%
show_images(mask)

# %%
def images_compare(inputs,mask):
    idx_new=np.random.randint(0,len(mask))
    fig = plt.figure()
    ax1 = fig.add_subplot(1,2,1)
    ax1.imshow(mask[idx_new])
    ax2 = fig.add_subplot(1,2,2)
    ax2.imshow(inputs[idx_new],cmap='gray')
    plt.show()
images_compare(inputs,mask)

# %% [markdown]
#  <div style="color:black;
#            display:fill;
#            border-radius:5px;
#            font-size:300%;
#            font-family: Times New Roman, Times, serif;
#     letter-spacing:0.5px"><b>Labeling using K-means</b>
#
# <p style="padding: 10px;color:black;font-size:40%;font-family: Times New Roman, Times, serif;">Although each pixel in these images is labeled, it was still necessary to separate the different colors to labels. K-means will be used to categorize these colored labels into ten different groups. This is a hyperparameter. The next few labeled images will be shown, followed by rescaling of the original image.</p>

# %%
num_items = 1000
color_array = np.random.choice(range(256), 3*num_items).reshape(-1,3)
num_classes = 20
label_model = KMeans(n_clusters = num_classes)
label_model.fit(color_array)
label_class = label_model.predict(mask[10].reshape(-1,3)).reshape(256,256)
fig, axes = plt.subplots(1,3,figsize=(15,5))
axes[0].imshow(inputs[10]);
axes[1].imshow(mask[10]);
axes[2].imshow(label_class);

# %%
def new_labels(mask):
    num_items = 1000
    color_array = np.random.choice(range(256), 3*num_items).reshape(-1,3)
    num_classes = 10
    label_model = KMeans(n_clusters = num_classes)
    label_model.fit(color_array)
    labels=[]
    for i in tqdm(range(len(mask))):
        label_class = label_model.predict(mask[i].reshape(-1,3)).reshape(256,256)
        labels.append(label_class)
    return labels

# %%
labels=new_labels(mask)
idx=np.random.randint(0,len(labels))
classes,freq=np.unique(labels[idx],return_counts=True)
print(f'number of classes :{len(classes)}')
# Out:
# 100%|██████████| 6950/6950 [00:26<00:00, 258.40it/s]
# number of classes :10

# %%
plt.figure(figsize=(10,10))
for i in range(9):
        plt.subplot(3,3,i+1)
        im=labels[i]
        plt.imshow(im)
# plt.imshow(a)

# %%
def rescale(data):
    rescaled=[]
    for i in tqdm(data):
        img=tf.image.convert_image_dtype(i, tf.float32)
        del i
        rescaled.append(img)
    return rescaled

# %%
rescaled_input=rescale(inputs)
# Out:
# 100%|██████████| 6950/6950 [00:06<00:00, 1112.87it/s]

# %% [markdown]
#  <div style="color:black;
#            display:fill;
#            border-radius:5px;
#            font-size:300%;
#            font-family: Times New Roman, Times, serif;
#     letter-spacing:0.5px"><b>Buliding the model</b>
#
# <p style="padding: 10px;color:black;font-size:40%;font-family: Times New Roman, Times, serif;"> Here I'm using UNet since the position of the object is crucial for this task. The feature map is upsampled to the size of the original input image using a transposed convolution layer that preserves the spatial information. It also includes skip connections, which help to keep information that would otherwise be lost during encoding. This model is kind of mini-VGG. </p>

# %%
def build_model(inputsize=(256,256,3),classes=None):
    inputs = tf.keras.Input(shape=(inputsize))

    conv = tfl.Conv2D(32, (3, 3), padding="same",kernel_initializer='he_normal', name='Conv1')(
        inputs)
    x=tfl.BatchNormalization()(conv)
    x=tfl.LeakyReLU()(x)
    x1 = tfl.Conv2D(32, (3, 3), padding="same",kernel_initializer='he_normal', name='Conv2')(
        x)
    x=tfl.BatchNormalization()(x1)
    x=tfl.LeakyReLU()(x)
    x = tfl.MaxPool2D(pool_size=(2, 2), strides=(2, 2), name='MaxPool1')(x)

    x = tfl.Conv2D(64, (3, 3), padding="same",kernel_initializer='he_normal', name='Conv3')(x)
    x=tfl.BatchNormalization()(x)
    x=tfl.LeakyReLU()(x)
    x2 = tfl.Conv2D(64, (3, 3), padding="same",kernel_initializer='he_normal', name='Conv4')(x)
    x=tfl.BatchNormalization()(x2)
    x=tfl.LeakyReLU()(x)
    x = tfl.MaxPool2D(pool_size=(2, 2), name='MaxPool2')(x)

    x = tfl.Conv2D(128, (3, 3), padding="same",kernel_initializer='he_normal', name='Conv5')(x)
    x=tfl.BatchNormalization()(x)
    x=tfl.LeakyReLU()(x)
    x3 = tfl.Conv2D(128, (3, 3), padding="same",kernel_initializer='he_normal', name='Conv6')(x)
    x=tfl.BatchNormalization()(x3)
    x=tfl.LeakyReLU()(x)
    x = tfl.MaxPool2D(pool_size=(2, 2), strides=(2, 2), name='MaxPool3')(x)

    
    x = tfl.Conv2D(256, (3, 3), padding="same",kernel_initializer='he_normal', name='Conv7')(x)
    x=tfl.BatchNormalization()(x)
    x=tfl.LeakyReLU()(x)
    x = tfl.Conv2D(256, (3, 3), padding="same",kernel_initializer='he_normal', name='Conv8')(x)
    x=tfl.BatchNormalization()(x)
    x=tfl.LeakyReLU()(x)
    
    x = tfl.Conv2DTranspose(128, (3, 3), strides=2, padding="same")(x)
    x=tfl.BatchNormalization()(x)
    x=tfl.LeakyReLU()(x)

    x = tfl.concatenate([x, x3], axis=3)
    
    x = tfl.Conv2D(128, (3, 3), padding="same",kernel_initializer='he_normal', name='Conv9')(x)
    x=tfl.BatchNormalization()(x)
    x=tfl.LeakyReLU()(x)
    x = tfl.Conv2D(128, (3, 3), padding="same",kernel_initializer='he_normal', name='Conv10')(x)
    x=tfl.BatchNormalization()(x)
    x=tfl.LeakyReLU()(x)
    x = tfl.Conv2DTranspose(64, (3, 3), strides=2, padding="same")(x)
    x=tfl.BatchNormalization()(x)
    x=tfl.LeakyReLU()(x)

    x = tfl.concatenate([x, x2], axis=3)

    x = tfl.Conv2D(64, (3, 3), padding="same",kernel_initializer='he_normal', name='Conv11')(x)
    x=tfl.BatchNormalization()(x)
    x=tfl.LeakyReLU()(x)
    x = tfl.Conv2D(64, (3, 3), padding="same",kernel_initializer='he_normal', name='Conv12')(x)
    x=tfl.BatchNormalization()(x)
    x=tfl.LeakyReLU()(x)
    
    x = tfl.Conv2DTranspose(32, (3, 3), strides=2, padding="same")(x)
    x=tfl.BatchNormalization()(x)
    x=tfl.LeakyReLU()(x)

    x = tfl.concatenate([x, x1], axis=3)

    x = tfl.Conv2D(32, (3, 3), padding="same",kernel_initializer='he_normal', name='Conv25')(x)
    x=tfl.BatchNormalization()(x)
    x=tfl.LeakyReLU()(x)
    x = tfl.Conv2D(32, (3, 3), padding="same",kernel_initializer='he_normal', name='Conv26')(x)
    x=tfl.BatchNormalization()(x)
    x=tfl.LeakyReLU()(x)
    
    outputs = tfl.Conv2D(classes, (1, 1), padding="same", activation='softmax', name='Outputs')(x)
    final_model = tf.keras.Model(inputs=inputs, outputs=outputs)
    final_model.summary()
    return final_model

# %%
mymodel=build_model(classes=10)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 256, 256, 32) 896         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 256, 256, 32) 128         Conv1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 256, 256, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# Conv2 (Conv2D)                  (None, 256, 256, 32) 9248        leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 256, 256, 32) 128         Conv2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 256, 256, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# MaxPool1 (MaxPooling2D)         (None, 128, 128, 32) 0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# Conv3 (Conv2D)                  (None, 128, 128, 64) 18496       MaxPool1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 128, 128, 64) 256         Conv3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 128, 128, 64) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# Conv4 (Conv2D)                  (None, 128, 128, 64) 36928       leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 128, 128, 64) 256         Conv4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 128, 128, 64) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# MaxPool2 (MaxPooling2D)         (None, 64, 64, 64)   0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# Conv5 (Conv2D)                  (None, 64, 64, 128)  73856       MaxPool2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 64, 64, 128)  512         Conv5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 64, 64, 128)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# Conv6 (Conv2D)                  (None, 64, 64, 128)  147584      leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 64, 64, 128)  512         Conv6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 64, 64, 128)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# MaxPool3 (MaxPooling2D)         (None, 32, 32, 128)  0           leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# Conv7 (Conv2D)                  (None, 32, 32, 256)  295168      MaxPool3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 256)  1024        Conv7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 32, 32, 256)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# Conv8 (Conv2D)                  (None, 32, 32, 256)  590080      leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 256)  1024        Conv8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 32, 32, 256)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 64, 64, 128)  295040      leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 64, 64, 128)  512         conv2d_transpose[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 64, 64, 128)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 64, 64, 256)  0           leaky_re_lu_8[0][0]
#                                                                  Conv6[0][0]
# __________________________________________________________________________________________________
# Conv9 (Conv2D)                  (None, 64, 64, 128)  295040      concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 64, 64, 128)  512         Conv9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 64, 64, 128)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# Conv10 (Conv2D)                 (None, 64, 64, 128)  147584      leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 64, 64, 128)  512         Conv10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 64, 64, 128)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 128, 128, 64) 73792       leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 128, 128, 64) 256         conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 128, 128, 64) 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 128, 128, 128 0           leaky_re_lu_11[0][0]
#                                                                  Conv4[0][0]
# __________________________________________________________________________________________________
# Conv11 (Conv2D)                 (None, 128, 128, 64) 73792       concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 128, 128, 64) 256         Conv11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 128, 128, 64) 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# Conv12 (Conv2D)                 (None, 128, 128, 64) 36928       leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 128, 128, 64) 256         Conv12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 128, 128, 64) 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 256, 256, 32) 18464       leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 256, 256, 32) 128         conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 256, 256, 32) 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 256, 256, 64) 0           leaky_re_lu_14[0][0]
#                                                                  Conv2[0][0]
# __________________________________________________________________________________________________
# Conv25 (Conv2D)                 (None, 256, 256, 32) 18464       concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 256, 256, 32) 128         Conv25[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 256, 256, 32) 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# Conv26 (Conv2D)                 (None, 256, 256, 32) 9248        leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 256, 256, 32) 128         Conv26[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 256, 256, 32) 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# Outputs (Conv2D)                (None, 256, 256, 10) 330         leaky_re_lu_16[0][0]
# ==================================================================================================
# Total params: 2,147,466
# Trainable params: 2,144,202
# Non-trainable params: 3,264
# __________________________________________________________________________________________________

# %%
img_file = './model_arch.png'

tf.keras.utils.plot_model(mymodel, to_file=img_file, show_shapes=True, show_layer_names=True)

# %%
del inputs

# %% [markdown]
#  <div style="color:black;
#            display:fill;
#            border-radius:5px;
#            font-size:300%;
#            font-family: Times New Roman, Times, serif;
#     letter-spacing:0.5px"><b>Training the model</b>
#
# <p style="padding: 10px;color:black;font-size:40%;font-family: Times New Roman, Times, serif;"> The data is divided into train and test segments, with each segment accounting for 80% and 20% of the total. To prevent RAM memory from crashing, I'm using 1300 images. Because the model's output employs 'softmax' activation layer, the loss function is sparse categorical crossentropy. Next, I'm going to use argmax to return the index with the highest value, and then I'm going to make some predictions for the test.</p>

# %%
def split_data(x,y,test_size=0.2):
    x1=np.array(x)
    del x
    y1=np.array(y)
    del y
    x_train, x_test, y_train, y_test = train_test_split(x1, y1, test_size=test_size)
    return  x_train, x_test, y_train, y_test

# %%
 x_train, x_test, y_train, y_test=split_data(rescaled_input[:1300],labels[:1300],test_size=0.2)

# %%
def callbacks(patience=5):
    checkpoint = tf.keras.callbacks.ModelCheckpoint('seg_model.h5', monitor='loss', verbose=1, save_best_only=True, save_weights_only=True)
    early=tf.keras.callbacks.EarlyStopping(monitor='loss',patience=patience)
    callbacks_list=[checkpoint, early]
    return callbacks_list

# %%
mymodel.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),loss=tf.keras.losses.sparse_categorical_crossentropy,metrics=['acc'])
hist=mymodel.fit(x_train,y_train,batch_size=16,epochs=200,callbacks=callbacks())
# Out:
# Epoch 1/200
# 65/65 [==============================] - 21s 176ms/step - loss: 1.1902 - acc: 0.5924
#
# Epoch 00001: loss improved from inf to 1.19018, saving model to seg_model.h5
# Epoch 2/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.9094 - acc: 0.6811
#
# Epoch 00002: loss improved from 1.19018 to 0.90940, saving model to seg_model.h5
# Epoch 3/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.8429 - acc: 0.7048
#
# Epoch 00003: loss improved from 0.90940 to 0.84290, saving model to seg_model.h5
# Epoch 4/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.7963 - acc: 0.7230
#
# Epoch 00004: loss improved from 0.84290 to 0.79632, saving model to seg_model.h5
# Epoch 5/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.7649 - acc: 0.7360
#
# Epoch 00005: loss improved from 0.79632 to 0.76494, saving model to seg_model.h5
# Epoch 6/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.7424 - acc: 0.7434
#
# Epoch 00006: loss improved from 0.76494 to 0.74242, saving model to seg_model.h5
# Epoch 7/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.7163 - acc: 0.7539
#
# Epoch 00007: loss improved from 0.74242 to 0.71629, saving model to seg_model.h5
# Epoch 8/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.7005 - acc: 0.7606
#
# Epoch 00008: loss improved from 0.71629 to 0.70050, saving model to seg_model.h5
# Epoch 9/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.6711 - acc: 0.7697
#
# Epoch 00009: loss improved from 0.70050 to 0.67112, saving model to seg_model.h5
# Epoch 10/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.6634 - acc: 0.7728
#
# Epoch 00010: loss improved from 0.67112 to 0.66336, saving model to seg_model.h5
# Epoch 11/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.6511 - acc: 0.7774
#
# Epoch 00011: loss improved from 0.66336 to 0.65106, saving model to seg_model.h5
# Epoch 12/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.6312 - acc: 0.7843
#
# Epoch 00012: loss improved from 0.65106 to 0.63117, saving model to seg_model.h5
# Epoch 13/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.6211 - acc: 0.7884
#
# Epoch 00013: loss improved from 0.63117 to 0.62114, saving model to seg_model.h5
# Epoch 14/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.6201 - acc: 0.7881
#
# Epoch 00014: loss improved from 0.62114 to 0.62011, saving model to seg_model.h5
# Epoch 15/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.6072 - acc: 0.7924
#
# Epoch 00015: loss improved from 0.62011 to 0.60717, saving model to seg_model.h5
# Epoch 16/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.5974 - acc: 0.7951
#
# Epoch 00016: loss improved from 0.60717 to 0.59743, saving model to seg_model.h5
# Epoch 17/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.5883 - acc: 0.7975
#
# Epoch 00017: loss improved from 0.59743 to 0.58835, saving model to seg_model.h5
# Epoch 18/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.5815 - acc: 0.8004
#
# Epoch 00018: loss improved from 0.58835 to 0.58148, saving model to seg_model.h5
# Epoch 19/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.5710 - acc: 0.8029
#
# Epoch 00019: loss improved from 0.58148 to 0.57097, saving model to seg_model.h5
# Epoch 20/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.5691 - acc: 0.8032
#
# Epoch 00020: loss improved from 0.57097 to 0.56909, saving model to seg_model.h5
# Epoch 21/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.5627 - acc: 0.8051
#
# Epoch 00021: loss improved from 0.56909 to 0.56266, saving model to seg_model.h5
# Epoch 22/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.5523 - acc: 0.8089
#
# Epoch 00022: loss improved from 0.56266 to 0.55232, saving model to seg_model.h5
# Epoch 23/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.5494 - acc: 0.8096
#
# Epoch 00023: loss improved from 0.55232 to 0.54937, saving model to seg_model.h5
# Epoch 24/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.5558 - acc: 0.8072
#
# Epoch 00024: loss did not improve from 0.54937
# Epoch 25/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.5352 - acc: 0.8148
#
# Epoch 00025: loss improved from 0.54937 to 0.53524, saving model to seg_model.h5
# Epoch 26/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.5318 - acc: 0.8149
#
# Epoch 00026: loss improved from 0.53524 to 0.53177, saving model to seg_model.h5
# Epoch 27/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.5297 - acc: 0.8162
#
# Epoch 00027: loss improved from 0.53177 to 0.52970, saving model to seg_model.h5
# Epoch 28/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.5274 - acc: 0.8168
#
# Epoch 00028: loss improved from 0.52970 to 0.52739, saving model to seg_model.h5
# Epoch 29/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.5280 - acc: 0.8165
#
# Epoch 00029: loss did not improve from 0.52739
# Epoch 30/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.5128 - acc: 0.8216
#
# Epoch 00030: loss improved from 0.52739 to 0.51278, saving model to seg_model.h5
# Epoch 31/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.5141 - acc: 0.8206
#
# Epoch 00031: loss did not improve from 0.51278
# Epoch 32/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.5142 - acc: 0.8215
#
# Epoch 00032: loss did not improve from 0.51278
# Epoch 33/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.5033 - acc: 0.8240
#
# Epoch 00033: loss improved from 0.51278 to 0.50328, saving model to seg_model.h5
# Epoch 34/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.5028 - acc: 0.8242
#
# Epoch 00034: loss improved from 0.50328 to 0.50284, saving model to seg_model.h5
# Epoch 35/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.4934 - acc: 0.8269
#
# Epoch 00035: loss improved from 0.50284 to 0.49344, saving model to seg_model.h5
# Epoch 36/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.4973 - acc: 0.8258
#
# Epoch 00036: loss did not improve from 0.49344
# Epoch 37/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.4869 - acc: 0.8293
#
# Epoch 00037: loss improved from 0.49344 to 0.48693, saving model to seg_model.h5
# Epoch 38/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.4862 - acc: 0.8292
#
# Epoch 00038: loss improved from 0.48693 to 0.48619, saving model to seg_model.h5
# Epoch 39/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.4741 - acc: 0.8332
#
# Epoch 00039: loss improved from 0.48619 to 0.47414, saving model to seg_model.h5
# Epoch 40/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.4702 - acc: 0.8341
#
# Epoch 00040: loss improved from 0.47414 to 0.47023, saving model to seg_model.h5
# Epoch 41/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.4658 - acc: 0.8360
#
# Epoch 00041: loss improved from 0.47023 to 0.46583, saving model to seg_model.h5
# Epoch 42/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.4682 - acc: 0.8348
#
# Epoch 00042: loss did not improve from 0.46583
# Epoch 43/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.4716 - acc: 0.8341
#
# Epoch 00043: loss did not improve from 0.46583
# Epoch 44/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.4609 - acc: 0.8378
#
# Epoch 00044: loss improved from 0.46583 to 0.46091, saving model to seg_model.h5
# Epoch 45/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.4616 - acc: 0.8370
#
# Epoch 00045: loss did not improve from 0.46091
# Epoch 46/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.4595 - acc: 0.8367
#
# Epoch 00046: loss improved from 0.46091 to 0.45948, saving model to seg_model.h5
# Epoch 47/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.4479 - acc: 0.8410
#
# Epoch 00047: loss improved from 0.45948 to 0.44791, saving model to seg_model.h5
# Epoch 48/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.4494 - acc: 0.8397
#
# Epoch 00048: loss did not improve from 0.44791
# Epoch 49/200
# 65/65 [==============================] - 11s 177ms/step - loss: 0.4390 - acc: 0.8438
#
# Epoch 00049: loss improved from 0.44791 to 0.43905, saving model to seg_model.h5
# Epoch 50/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.4406 - acc: 0.8429
#
# Epoch 00050: loss did not improve from 0.43905
# Epoch 51/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.4373 - acc: 0.8435
#
# Epoch 00051: loss improved from 0.43905 to 0.43726, saving model to seg_model.h5
# Epoch 52/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.4244 - acc: 0.8476
#
# Epoch 00052: loss improved from 0.43726 to 0.42444, saving model to seg_model.h5
# Epoch 53/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.4372 - acc: 0.8434
#
# Epoch 00053: loss did not improve from 0.42444
# Epoch 54/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.4240 - acc: 0.8479
#
# Epoch 00054: loss improved from 0.42444 to 0.42402, saving model to seg_model.h5
# Epoch 55/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.4227 - acc: 0.8482
#
# Epoch 00055: loss improved from 0.42402 to 0.42266, saving model to seg_model.h5
# Epoch 56/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.4170 - acc: 0.8500
#
# Epoch 00056: loss improved from 0.42266 to 0.41701, saving model to seg_model.h5
# Epoch 57/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.4121 - acc: 0.8521
#
# Epoch 00057: loss improved from 0.41701 to 0.41212, saving model to seg_model.h5
# Epoch 58/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.4091 - acc: 0.8529
#
# Epoch 00058: loss improved from 0.41212 to 0.40908, saving model to seg_model.h5
# Epoch 59/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.4044 - acc: 0.8540
#
# Epoch 00059: loss improved from 0.40908 to 0.40444, saving model to seg_model.h5
# Epoch 60/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.4097 - acc: 0.8518
#
# Epoch 00060: loss did not improve from 0.40444
# Epoch 61/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.3965 - acc: 0.8571
#
# Epoch 00061: loss improved from 0.40444 to 0.39653, saving model to seg_model.h5
# Epoch 62/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.3960 - acc: 0.8566
#
# Epoch 00062: loss improved from 0.39653 to 0.39600, saving model to seg_model.h5
# Epoch 63/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.3898 - acc: 0.8586
#
# Epoch 00063: loss improved from 0.39600 to 0.38975, saving model to seg_model.h5
# Epoch 64/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.3984 - acc: 0.8558
#
# Epoch 00064: loss did not improve from 0.38975
# Epoch 65/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.3823 - acc: 0.8613
#
# Epoch 00065: loss improved from 0.38975 to 0.38228, saving model to seg_model.h5
# Epoch 66/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.3736 - acc: 0.8640
#
# Epoch 00066: loss improved from 0.38228 to 0.37364, saving model to seg_model.h5
# Epoch 67/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.3782 - acc: 0.8625
#
# Epoch 00067: loss did not improve from 0.37364
# Epoch 68/200
# 65/65 [==============================] - 11s 177ms/step - loss: 0.3741 - acc: 0.8641
#
# Epoch 00068: loss did not improve from 0.37364
# Epoch 69/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.3710 - acc: 0.8649
#
# Epoch 00069: loss improved from 0.37364 to 0.37097, saving model to seg_model.h5
# Epoch 70/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.3659 - acc: 0.8669
#
# Epoch 00070: loss improved from 0.37097 to 0.36585, saving model to seg_model.h5
# Epoch 71/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.3574 - acc: 0.8693
#
# Epoch 00071: loss improved from 0.36585 to 0.35740, saving model to seg_model.h5
# Epoch 72/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.3539 - acc: 0.8705
#
# Epoch 00072: loss improved from 0.35740 to 0.35389, saving model to seg_model.h5
# Epoch 73/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.3545 - acc: 0.8698
#
# Epoch 00073: loss did not improve from 0.35389
# Epoch 74/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.3571 - acc: 0.8692
#
# Epoch 00074: loss did not improve from 0.35389
# Epoch 75/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.3486 - acc: 0.8720
#
# Epoch 00075: loss improved from 0.35389 to 0.34855, saving model to seg_model.h5
# Epoch 76/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.3490 - acc: 0.8719
#
# Epoch 00076: loss did not improve from 0.34855
# Epoch 77/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.3513 - acc: 0.8708
#
# Epoch 00077: loss did not improve from 0.34855
# Epoch 78/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.3415 - acc: 0.8747
#
# Epoch 00078: loss improved from 0.34855 to 0.34155, saving model to seg_model.h5
# Epoch 79/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.3334 - acc: 0.8775
#
# Epoch 00079: loss improved from 0.34155 to 0.33345, saving model to seg_model.h5
# Epoch 80/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.3365 - acc: 0.8766
#
# Epoch 00080: loss did not improve from 0.33345
# Epoch 81/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.3235 - acc: 0.8808
#
# Epoch 00081: loss improved from 0.33345 to 0.32354, saving model to seg_model.h5
# Epoch 82/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.3319 - acc: 0.8776
#
# Epoch 00082: loss did not improve from 0.32354
# Epoch 83/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.3209 - acc: 0.8812
#
# Epoch 00083: loss improved from 0.32354 to 0.32093, saving model to seg_model.h5
# Epoch 84/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.3189 - acc: 0.8821
#
# Epoch 00084: loss improved from 0.32093 to 0.31892, saving model to seg_model.h5
# Epoch 85/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.3093 - acc: 0.8854
#
# Epoch 00085: loss improved from 0.31892 to 0.30929, saving model to seg_model.h5
# Epoch 86/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.3159 - acc: 0.8830
#
# Epoch 00086: loss did not improve from 0.30929
# Epoch 87/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.3116 - acc: 0.8843
#
# Epoch 00087: loss did not improve from 0.30929
# Epoch 88/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.3040 - acc: 0.8871
#
# Epoch 00088: loss improved from 0.30929 to 0.30396, saving model to seg_model.h5
# Epoch 89/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.3018 - acc: 0.8878
#
# Epoch 00089: loss improved from 0.30396 to 0.30184, saving model to seg_model.h5
# Epoch 90/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.3130 - acc: 0.8839
#
# Epoch 00090: loss did not improve from 0.30184
# Epoch 91/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.3271 - acc: 0.8793
#
# Epoch 00091: loss did not improve from 0.30184
# Epoch 92/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.3049 - acc: 0.8870
#
# Epoch 00092: loss did not improve from 0.30184
# Epoch 93/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.2901 - acc: 0.8916
#
# Epoch 00093: loss improved from 0.30184 to 0.29014, saving model to seg_model.h5
# Epoch 94/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.2980 - acc: 0.8890
#
# Epoch 00094: loss did not improve from 0.29014
# Epoch 95/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.2931 - acc: 0.8908
#
# Epoch 00095: loss did not improve from 0.29014
# Epoch 96/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.2820 - acc: 0.8942
#
# Epoch 00096: loss improved from 0.29014 to 0.28198, saving model to seg_model.h5
# Epoch 97/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.2787 - acc: 0.8954
#
# Epoch 00097: loss improved from 0.28198 to 0.27872, saving model to seg_model.h5
# Epoch 98/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.2782 - acc: 0.8956
#
# Epoch 00098: loss improved from 0.27872 to 0.27819, saving model to seg_model.h5
# Epoch 99/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.2761 - acc: 0.8965
#
# Epoch 00099: loss improved from 0.27819 to 0.27612, saving model to seg_model.h5
# Epoch 100/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.2779 - acc: 0.8956
#
# Epoch 00100: loss did not improve from 0.27612
# Epoch 101/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.2905 - acc: 0.8911
#
# Epoch 00101: loss did not improve from 0.27612
# Epoch 102/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.2740 - acc: 0.8969
#
# Epoch 00102: loss improved from 0.27612 to 0.27397, saving model to seg_model.h5
# Epoch 103/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.2686 - acc: 0.8988
#
# Epoch 00103: loss improved from 0.27397 to 0.26856, saving model to seg_model.h5
# Epoch 104/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.2665 - acc: 0.8994
#
# Epoch 00104: loss improved from 0.26856 to 0.26645, saving model to seg_model.h5
# Epoch 105/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.2638 - acc: 0.9000
#
# Epoch 00105: loss improved from 0.26645 to 0.26378, saving model to seg_model.h5
# Epoch 106/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.2841 - acc: 0.8933
#
# Epoch 00106: loss did not improve from 0.26378
# Epoch 107/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.3196 - acc: 0.8820
#
# Epoch 00107: loss did not improve from 0.26378
# Epoch 108/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.3279 - acc: 0.8795
#
# Epoch 00108: loss did not improve from 0.26378
# Epoch 109/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.2762 - acc: 0.8963
#
# Epoch 00109: loss did not improve from 0.26378
# Epoch 110/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.2612 - acc: 0.9012
#
# Epoch 00110: loss improved from 0.26378 to 0.26117, saving model to seg_model.h5
# Epoch 111/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.2548 - acc: 0.9030
#
# Epoch 00111: loss improved from 0.26117 to 0.25483, saving model to seg_model.h5
# Epoch 112/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.2537 - acc: 0.9035
#
# Epoch 00112: loss improved from 0.25483 to 0.25373, saving model to seg_model.h5
# Epoch 113/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.2507 - acc: 0.9043
#
# Epoch 00113: loss improved from 0.25373 to 0.25067, saving model to seg_model.h5
# Epoch 114/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.2489 - acc: 0.9050
#
# Epoch 00114: loss improved from 0.25067 to 0.24890, saving model to seg_model.h5
# Epoch 115/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.2467 - acc: 0.9056
#
# Epoch 00115: loss improved from 0.24890 to 0.24672, saving model to seg_model.h5
# Epoch 116/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.2551 - acc: 0.9026
#
# Epoch 00116: loss did not improve from 0.24672
# Epoch 117/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.2490 - acc: 0.9048
#
# Epoch 00117: loss did not improve from 0.24672
# Epoch 118/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.2460 - acc: 0.9058
#
# Epoch 00118: loss improved from 0.24672 to 0.24604, saving model to seg_model.h5
# Epoch 119/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.2553 - acc: 0.9025
#
# Epoch 00119: loss did not improve from 0.24604
# Epoch 120/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.2544 - acc: 0.9034
#
# Epoch 00120: loss did not improve from 0.24604
# Epoch 121/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.2853 - acc: 0.8928
#
# Epoch 00121: loss did not improve from 0.24604
# Epoch 122/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.2542 - acc: 0.9033
#
# Epoch 00122: loss did not improve from 0.24604
# Epoch 123/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.2419 - acc: 0.9071
#
# Epoch 00123: loss improved from 0.24604 to 0.24189, saving model to seg_model.h5
# Epoch 124/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.2383 - acc: 0.9082
#
# Epoch 00124: loss improved from 0.24189 to 0.23832, saving model to seg_model.h5
# Epoch 125/200
# 65/65 [==============================] - 11s 177ms/step - loss: 0.2358 - acc: 0.9090
#
# Epoch 00125: loss improved from 0.23832 to 0.23583, saving model to seg_model.h5
# Epoch 126/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.2342 - acc: 0.9096
#
# Epoch 00126: loss improved from 0.23583 to 0.23420, saving model to seg_model.h5
# Epoch 127/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.2469 - acc: 0.9053
#
# Epoch 00127: loss did not improve from 0.23420
# Epoch 128/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.2525 - acc: 0.9035
#
# Epoch 00128: loss did not improve from 0.23420
# Epoch 129/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.2403 - acc: 0.9075
#
# Epoch 00129: loss did not improve from 0.23420
# Epoch 130/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.2330 - acc: 0.9099
#
# Epoch 00130: loss improved from 0.23420 to 0.23300, saving model to seg_model.h5
# Epoch 131/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.2367 - acc: 0.9086
#
# Epoch 00131: loss did not improve from 0.23300
# Epoch 132/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.2356 - acc: 0.9087
#
# Epoch 00132: loss did not improve from 0.23300
# Epoch 133/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.2609 - acc: 0.9007
#
# Epoch 00133: loss did not improve from 0.23300
# Epoch 134/200
# 65/65 [==============================] - 11s 176ms/step - loss: 0.2546 - acc: 0.9027
#
# Epoch 00134: loss did not improve from 0.23300
# Epoch 135/200
# 65/65 [==============================] - 11s 175ms/step - loss: 0.2664 - acc: 0.8988
#
# Epoch 00135: loss did not improve from 0.23300

# %%
plt.plot(hist.history['loss'])
plt.title("model loss")
plt.ylabel("Loss")
plt.xlabel("Epochs")
plt.show()

# %%
plt.plot(hist.history["acc"])
plt.title("model accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epochs")
plt.show()

# %%
pred=mymodel.predict(x_test)
y_pred=tf.argmax(pred,axis=-1)

# %%
def show_predications(x_test,y_test,y_pred):
    idx=np.random.randint(0,len(y_pred))
    fig, axes = plt.subplots(1,3,figsize=(10,10))
    axes[0].imshow(x_test[idx])
    axes[0].set_title("original")
    axes[1].imshow(y_test[idx])
    axes[1].set_title("mask")
    axes[2].imshow(y_pred[idx])
    axes[2].set_title("predicated")

# %%
for i in range(3):
    show_predications(x_test,y_test,y_pred)

# %% [markdown]
#  <div style="color:black;
#            display:fill;
#            border-radius:5px;
#            font-size:300%;
#            font-family: Times New Roman, Times, serif;
#     letter-spacing:0.5px"><b>Testing the model</b>

# %%
import cv2
import numpy as np

# Load the image
new_image = cv2.imread('/kaggle/input/testdata/1.jpeg')

# Preprocess the image
new_image = cv2.resize(new_image, (256, 256))
new_image = new_image / 255.0
new_image = np.expand_dims(new_image, axis=0)

# Predict the segmentation mask
pred = mymodel.predict(new_image)
y_pred = np.argmax(pred, axis=-1)

# Show the results
plt.imshow(y_pred[0])
plt.show()
# Show real image 
plt.imshow(new_image[0])
plt.show()

# %%
import cv2
import numpy as np

# Load the image
new_image = cv2.imread('/kaggle/input/testdata/3.jpeg')

# Preprocess the image
new_image = cv2.resize(new_image, (256, 256))
new_image = new_image / 255.0
new_image = np.expand_dims(new_image, axis=0)

# Predict the segmentation mask
pred = mymodel.predict(new_image)
y_pred = np.argmax(pred, axis=-1)

# Show the results
plt.imshow(y_pred[0])
plt.show()
# Show the results
plt.imshow(new_image[0])
plt.show()

# %%
"""import cv2
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# load the video and extract the frames
cap = cv2.VideoCapture('/kaggle/input/testvideo/traffic-27260.mp4')
frames = []
while True:
    ret, frame = cap.read()
    if not ret:
        break
    frames.append(frame)
cap.release()

# preprocess the frames
frames = np.array(frames)
frames = frames / 255.0  # normalize the pixel values
frames = tf.image.resize(frames, (128, 128))  # resize the frames

# feed the frames to your model
y_pred_video = mymodel.predict(frames)

# get the predicted output
y_pred_video = tf.argmax(y_pred_video, axis=-1)

# visualize the predicted output for a randomly selected frame
def show_predictions(frames, y_pred_video):
    idx = np.random.randint(0, len(y_pred_video))
    fig, axes = plt.subplots(1, 2, figsize=(10, 10))
    axes[0].imshow(frames[idx])
    axes[0].set_title("original")
    axes[1].imshow(y_pred_video[idx])
    axes[1].set_title("predicted")

show_predictions(frames, y_pred_video)"""
# Out:
# 'import cv2\nimport numpy as np\nimport tensorflow as tf\nimport matplotlib.pyplot as plt\n\n# load the video and extract the frames\ncap = cv2.VideoCapture(\'/kaggle/input/testvideo/traffic-27260.mp4\')\nframes = []\nwhile True:\n    ret, frame = cap.read()\n    if not ret:\n        break\n    frames.append(frame)\ncap.release()\n\n# preprocess the frames\nframes = np.array(frames)\nframes = frames / 255.0  # normalize the pixel values\nframes = tf.image.resize(frames, (128, 128))  # resize the frames\n\n# feed the frames to your model\ny_pred_video = mymodel.predict(frames)\n\n# get the predicted output\ny_pred_video = tf.argmax(y_pred_video, axis=-1)\n\n# visualize the predicted output for a randomly selected frame\ndef show_predictions(frames, y_pred_video):\n    idx = np.random.randint(0, len(y_pred_video))\n    fig, axes = plt.subplots(1, 2, figsize=(10, 10))\n    axes[0].imshow(frames[idx])\n    axes[0].set_title("original")\n    axes[1].imshow(y_pred_video[idx])\n    axes[1].set_title("predicted")\n\nshow_predictions(frames, y_pred_video)'

# %% [markdown]
#  <div style="color:black;
#            display:fill;
#            border-radius:5px;
#            font-size:300%;
#            font-family: Times New Roman, Times, serif;
#     letter-spacing:0.5px"><b>Conclusions</b>
#
# <p style="padding: 10px;color:black;font-size:40%;font-family: Times New Roman, Times, serif;">
# Despite the fact that the results are not amazing, they are not so bad. More layers, as well as augmentations and different class clustering, are required for even better results.</p>
